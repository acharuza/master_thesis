# %%
from matplotlib import pyplot as plt
from src.waveform_vis import visualize_echonext_ecg, visualize_echonext_ecg_scalogram

# %%
fig = visualize_echonext_ecg(
    "../data/EchoNext_train_waveforms.npy",
    index=44,
    layout="stacked"
)
plt.show()

# %%
fig = visualize_echonext_ecg(
    "../data/EchoNext_train_waveforms.npy",
    index=44,
    leads=[0, 1, 7, 8, 9, 10, 11],  # I, II, V1-V6
    layout="overlay",
    figsize=(12, 5)
)
plt.show()

# %%
fig = visualize_echonext_ecg_scalogram(
    "../data/EchoNext_train_waveforms.npy",
    index=44,
    wavelet='gaus1',
)
